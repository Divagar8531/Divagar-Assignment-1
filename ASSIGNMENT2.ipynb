# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np

# %%
import seaborn as sb

# %%
import pandas

# %%
from bs4 import BeautifulSoup

# %%
mb=pandas.read_csv("C:\\Users\\aedur\\OneDrive\\Desktop\\used_cars.csv")

# %%
mpp=mb.tail()

# %%
mpp
# Out:
#     id    brand       model  year  miles  city_mileage  highway_mileage  \
# 47  53  Hyundai      Sonata  2019  33412            23               32
# 48  54  Hyundai  Elantra SE  2020  13830            30               40
# 49  55     Ford      Fusion  2019  23507            20               29
# 50  56  Hyundai  Elantra SE  2020  11296            30               40
# 51  57    Honda      Accord  2018  82729            30               38
#
#     horsepower  torque  engine_capacity_litre  ...   type  doors  wheel_drive  \
# 47         245     260                    2.0  ...  sedan      4            2
# 48         147     132                    2.0  ...  sedan      4            2
# 49         245     275                    2.0  ...  sedan      4            2
# 50         147     132                    2.0  ...  sedan      4            2
# 51         192     192                    1.5  ...  sedan      4            2
#
# ...

# %%
plt.scatter(mpp['horsepower'],mpp['miles'])

# %%
plt.bar(mb['horsepower'],mb['miles'])
# Out:
# <BarContainer object of 52 artists>

# %%
plt.plot(mb['horsepower'],mb['miles'],linestyle='dotted')

# %%
plt.pie(mpp['horsepower'],labels=mpp['miles'])
# Out:
# ([<matplotlib.patches.Wedge at 0x1f9ef808c70>,
# ...
#  [Text(0.7753097268413016, 0.7803171326231831, '33412'),
#   Text(-0.5075745608970657, 0.9758934701749731, '13830'),
#   Text(-1.0840315924687471, -0.18674985014631793, '23507'),
#   Text(-0.1517655270588213, -1.0894802544316984, '11296'),
#   Text(0.8965312827908484, -0.6373630511548313, '82729')])

# %%
time=np.arange(0,1000,0.5)

# %%
time
# Out:
# array([0.000e+00, 5.000e-01, 1.000e+00, ..., 9.985e+02, 9.990e+02,
#        9.995e+02])

# %%
amplitude=np.sin(time)

# %%
amplitude
# Out:
# array([ 0.        ,  0.47942554,  0.84147098, ..., -0.50247916,
#        -0.02646075,  0.45603617])

# %%
plt.plot(time,amplitude)

# %%
plt.plot(mpp['horsepower'],mpp['miles'])

# %%
sb.set(style='darkgrid')

# %%
sb.distplot(mpp['horsepower'])
# Out:
# C:\Users\aedur\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='horsepower', ylabel='Density'>

# %%
mpp
# Out:
#     id    brand       model  year  miles  city_mileage  highway_mileage  \
# 47  53  Hyundai      Sonata  2019  33412            23               32
# 48  54  Hyundai  Elantra SE  2020  13830            30               40
# 49  55     Ford      Fusion  2019  23507            20               29
# 50  56  Hyundai  Elantra SE  2020  11296            30               40
# 51  57    Honda      Accord  2018  82729            30               38
#
#     horsepower  torque  engine_capacity_litre  ...   type  doors  wheel_drive  \
# 47         245     260                    2.0  ...  sedan      4            2
# 48         147     132                    2.0  ...  sedan      4            2
# 49         245     275                    2.0  ...  sedan      4            2
# 50         147     132                    2.0  ...  sedan      4            2
# 51         192     192                    1.5  ...  sedan      4            2
#
# ...

# %%
sb.relplot(x='horsepower',y='miles',data=mpp,col='horsepower',hue="torque",style="torque",kind="scatter")

# %%
sb.catplot(x='horsepower',y='miles',kind='box',data=mb)

# %%
sb.regplot(x='horsepower',y='miles',data=mb)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='miles'>

# %%
sb.pairplot(mpp)

# %%
sb.pairplot(mb,hue='horsepower',palette='Set1')
